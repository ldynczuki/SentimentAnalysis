# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm

# %%
def post_request(endpoint, json):
    result_post = []
    for post in tqdm(range(1)):
        post = requests.post(endpoint, verify=False, json=json).json()
        result_post.append(post)
    return result_post

# %%
endpoint = 'http://localhost:5000/api/database/find_query'

json_find_query = {
    'query': "#corinthians"
}

# %%
# %%time
send_post = post_request(endpoint, json_find_query)
send_post
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 54.98it/s]
# CPU times: user 16.9 ms, sys: 65 µs, total: 17 ms
# Wall time: 33.1 ms
# [{'resultado': [{'_id': '60abfd0918c8e8b052dbf258',
#     'date': '2021-05-24',
#     'text': 'Cartola fc 2021 vai começar e você não sabe em qual liga participar? Entre em A Liga do Willian e participe.   #cartola #cartolafc #brasileirao #futebol #corinthians #palmeiras #santos #saopaulo #flamengo  https://t.co/hPQmH1xHkG',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf259',
#     'date': '2021-05-24',
#     'text': 'O #Flamengo acertou o retorno para o SUB15 de David, artilheiro dos fez “172 gols”. David (na foto com Vitor Zanelli) tinha saído do #CRF em 2020, para jogar no #Corinthians, mas acabou retornando. Em 2019, o o garoto marcou 172 gols, sendo parte no futsal e outra no campo.  https://t.co/2tvR8aHgnT',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf25a',
#     'date': '2021-05-24',
#     'text': 'All the wisdom in the world is NOTHING—without love. ~KFaith (1 Corinthians 13:2) #holybible #corinthians #love #wisdom god  https://t.co/iIrJhVCgz8',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf25b',
#     'date': '2021-05-24',
#     'text': '#EXPERIÊNCIA E #FUTEBOL - #Sylvinho é o novo #treinador do #Corinthians.\xa0Mas um novato ao invés de um "cascudo" é o ideal para o momento? Em:\xa0 https://t.co/T30sXnZ1pO',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf25c',
#     'date': '2021-05-24',
#     'text': '@Corinthians anunciou neste domingo, 23, a contratação de #Sylvinho como novo treinador #Corinthians    https://t.co/vCnGj17lPm',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf25d',
#     'date': '2021-05-24',
#     'text': '@povotime1910 @centraldotimao @Corinthians tem que endireitar a coluna do Cantillo, ela é inclinada, mas uma boa fisioterapia coloca a coluna dele no lugar.  #Corinthians',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf25e',
#     'date': '2021-05-24',
#     'text': 'Ai ai ai, nao tenho tanto tempo assim de vida pra fica me preocupando com coisas desnecessárias! Assim não neeh #Corinthians',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf25f',
#     'date': '2021-05-24',
#     'text': 'Oi sou nova por aqui, me segue que sigo de volta. #Corinthians',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf260',
#     'date': '2021-05-24',
#     'text': 'Sylvinho não fará a sua estreia nesta quarta-feira, diante do River Plate (PAR).  O novo técnico do Timão deve fazer o seu primeiro jogo pelo clube no domingo, contra o Atlético-GO, na 1ª rodada do Brasileirão 2021.  #Corinthians #TimãoAnálise  https://t.co/6dGubIho5H',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf261',
#     'date': '2021-05-24',
#     'text': '#SãoPauloFc #Palmeiras #Corinthians #SantosFC #Flamengo #Fluminense #Grêmio #Internacional #AtléticoMG #AméricaMG #Paulistão #Carioca #Mineiro #Gauchão #Libertadores #CopaSulamericana  Fotos: Erico Leonan/SPFC Marcelo Cortes/Flamengo Pedro Souza/Atlético-MG Lucas Uebel/Grêmio',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf262',
#     'date': '2021-05-24',
#     'text': 'Alguém se deu bem nessa história todo envolvendo Renato Gaúcho e #Corinthians.   https://t.co/liVstRGts6',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052db

#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf26d',
#     'date': '2021-05-24',
#     'text': '- ⚽ @oficialbob13 (ex-#Corinthians, #Gremio e #Cruzeiro), 6G nos últimos 8J pelo #SydneyFC 🇦🇺  - ⚽ Dodo pelo #FKLiepaja 🇱🇻  - ⚽ Cesinha (atacante ex-#UniaoBarbarense, #Bragantino, #AtleticoMG e #PontePreta) com 🅰️ Edgar Silva (atacante ex-#Vasco) deram a vitória ao #Daegu 🇰🇷',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf26e',
#     'date': '2021-05-24',
#     'text': 'Corinthians X Palmeiras!!!  Corinthians e o maior!!!!  🦅Recopa sudamericana 1x 0 🦅Super copa do Brasil 1 x 0 🦅Copinha 10 x 0 🦅Paulista 30 x 23 🦅Brasileiro 7 x 6 (o correto) 🦅Copa do Br 3 x 4 🦅Libertadores 1 x 2 🦅Mundial 2 x0 🦅Torcida 30M x 12M  #Corinthians #Palmeiras',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf26f',
#     'date': '2021-05-24',
#     'text': 'Difícil entender qual critério técnico adotado pela diretoria do Corinthians. Renato Gaúcho, Aguirre e agora Sylvinho. O que eles têm em comum? Parece mais tiros aleatórios. #Corinthians',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf270',
#     'date': '2021-05-24',
#     'text': 'Gabriel Lima : 23 anos 👟 Meia Atacante ⚔️ 9 jogos (4 titular) ⚽ 0 gols 👟 0 assistências 🛡️ Metropolitano  #MeuTimão #Corinthians  https://t.co/XFnegcVXSd',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf271',
#     'date': '2021-05-24',
#     'text': 'Rafael Bilú : 24 anos 👟 Meia Atacante ⚔️ 1 jogo (1 titular) ⚽ 0 gols 👟 0 assistências 🛡️ Mirassol  #MeuTimão #Corinthians  https://t.co/lyZqaBODX9',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf272',
#     'date': '2021-05-24',
#     'text': 'Warian Ameixa: 24 anos 👟  Volante ⚔️ 8 jogos (7 titular) ⚽ 0 gols 👟 0 assistências ⚠️ 2 cartões vermelhos 🛡️ São Caetano  #MeuTimão #Corinthians  https://t.co/ysEOiySbv5',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf273',
#     'date': '2021-05-24',
#     'text': 'Thiaguinho : 24 anos 👟 Volante  ⚔️ 11 jogos (7 titular) ⚽ 0 gols 👟 0 assistências ⚠️ 1 cartão vermelho 🛡️ Inter de Limeira  #MeuTimão #Corinthians  https://t.co/fU6yKxbvFj',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf274',
#     'date': '2021-05-24',
#     'text': 'Emerson Sousa: 22 anos 👟 Volante ⚔️ 1 jogos (0 titular) ⚽ 0 gols 👟 0 assistências 🛡️ Coimbrã  #MeuTimão #Corinthians  https://t.co/8lteh7VTw2',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf275',
#     'date': '2021-05-24',
#     'text': 'Caetano : 21 anos  👟 Zagueiro ⚔️ 8 jogos (7 como titular) ⚽ 1 gol 👟 0 assistências ⚠️ 1 cartão vermelho 🛡️ São Caetano #MeuTimão #Corinthians  https://t.co/qGOUf4XHGc',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf276',
#     'date': '2021-05-24',
#     'text': 'Kevin Emmel: 20 anos 👟 Lateral Esquerdo ⚔️ 6 jogos (2 como titular) ⚽ 0 gols 👟 0 assistências 🛡️ Metropolitano  #MeuTimão #Corinthians  https://t.co/A2d3EIt0sI',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052db

#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf282',
#     'date': '2021-05-24',
#     'text': '#Sudamericana - #Sylvinho fue auxiliar técnico del #Corinthians con Adenor Leonardo Bacchi "Tite" y con Mano Menezes.  https://t.co/ckgNcrd92X',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf283',
#     'date': '2021-05-24',
#     'text': '#Sudamericana - #Sylvinho fue auxiliar técnico del #Corinthians con Adenor Leonardo Bacchi "Tite" y con Mano Menezes.  https://t.co/AApGrW2i8U',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf284',
#     'date': '2021-05-24',
#     'text': '#SegundaBestFriendsSDV #VaiCorinthians #Corinthians Boa semana Corinthianos .  https://t.co/JclOvkPvwc',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf285',
#     'date': '2021-05-24',
#     'text': '@rodolfo1975 Será que o #Corinthians ficou mesmo quase 23 anos na fila do Campeonato Paulista?  Que estranho. Vou pesquisar...',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf286',
#     'date': '2021-05-24',
#     'text': 'Corinthians e Palmeiras vencem e se isolam na ponta da tabela do Brasileiro Feminino - Olimpia Sports  #BrasileirãoFeminino #BrasileirãoA1 #Corinthians #Palmeiras #Líder #RespeitasasMina #elastemnome   https://t.co/mVXdgkVx8T',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf287',
#     'date': '2021-05-24',
#     'text': '1 #Corinthians 1:21 For since in the wisdom of ##God the world by its wisdom did not know ##God, ##God was pleased to save those who believe by the foolishness of preaching.',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf288',
#     'date': '2021-05-24',
#     'text': 'Esse Abel Ferreira ainda vai me matar de tanto rir, éh lasqueira, que treinador briguento! Kkkkkkkkkkkkkkkkkkkkkkk   #AbelFerreira #Palmeiras #Flamengo #Corinthians #saopaulofc #SAOxPAL',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf289',
#     'date': '2021-05-24',
#     'text': 'Sylvinho no Corinthians! Qual sua opinião? #sylvinho #Corinthians #MeuTimao #VaiCorinthians',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf28a',
#     'date': '2021-05-24',
#     'text': 'Alguem me contrata pra trabalhar no marketing do @Corinthians pq quem está lá do faz merda #Corinthians',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf28b',
#     'date': '2021-05-24',
#     'text': 'Muitos criticam a contratação do Sylvinho como técnico do #Corinthians, mas poucos sabem que ele fez história no Lyon da FRA  Qual sua opiniao @pepecarille ?   https://t.co/auZfjQ1MYR',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf28c',
#     'date': '2021-05-24',
#     'text': 'Até então, esse foi o Mlk da base que mais me agradou, RÁPIDO, CANHOTO, DRIBLE CURTO, E LONGO E INTELIGENTE, tem tudo para evoluí. Só não gostei do arremate dele, fora isso pode ser um belo jogador, e uma jóia para o Corinthians. #VaiCorinthians  #timao  #Corinthians  #Sylvinho',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf28d',
#     'date': '2021-05-24',
#     'text': '[7/7]》O que aliás, não interfere quando avalio que o tricolor paulista é maior que o alviverde.  Isso apenas me incomoda um pouco.  Afinal de contas, opino que o maior rival do #Corinthians é o Palmeiras que não é nem o segundo maior time do Estado de São Paulo.',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf28e',
#     'date': '2021-05-24',
#     'text': '[5/7]》Como pode ser tão freguês de um time que é tão massacrado pelo #Corinthians, quando não consegue impor a mesma disparidade na rivalidade?  Não a toa para muitos (inclusive corinthianos) a maior rivalidade no estado de São Paulo é o #Majestoso...',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf28f',
#     'date': '2021-05-24',
#     'text': '[4/7]》Quando projetou-se um #Majestoso na final, por pior que o #Corinthians estivesse, e está, a grande maioria (inclusive são-paulinos) se preocuparam em permanecer mais 1 ano na fila.  Os palmeirenses indignados perguntam-se há tempos...',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf290',
#     'date': '2021-05-24',
#     'text': 'O verdadeiro REI de São Paulo! #Corinthians #Timão #Sccp #Timedopovo #SãoPaulo #MaiordeSP  https://t.co/s2v7oYi9IX',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf291',
#     'date': '2021-05-24',
#     'text': 'Novo treinador tem história no clube como jogador e auxiliar técnico   https://t.co/X8NWcCNSAN   #Sylvinho #Corinthians #futebolpaulista #jornaldossports',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf292',
#     'date': '2021-05-24',
#     'text': 'Fiel torcida, o técnico do @Corinthians já foi escolhido. Calma.. Não adianta ficar zicando o cara. Deixa ele mostrar o que vai fazer! Quando o Carille foi oficializado, falaram a mesma coisa. Vamos apoiar! Se não rolar, a gente protesta. #VaiCorinthians #Corinthians #sccp',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf293',
#     'date': '2021-05-24',
#     'text': 'Bem Vindo Sylvinho! #Corinthians #Sylvinho #ModernoESerCorinthians  https://t.co/kIUCYo2kYx',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf294',
#     'date': '2021-05-24',
#     'text': 'O #Corinthians anunciou ontem (23) o acerto com o técnico Sylvinho para comandar a sua equipe de futebol profissional até o final de 2022.  https://t.co/enuXYanFwx',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf295',
#     'date': '2021-05-24',
#     'text': '@Corinthians Dando risada pra não chorar, TOMARE que dê certo.  #BoaSorteSylvinho  #Sylvinho  #Corinthians  #ModernoESerCorinthians  #VaiCorinthians',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf296',
#     'date': '2021-05-24',
#     'text': 'Dando risada pra não chorar, TOMARE que dê certo.  #BoaSorteSylvinho  #Sylvinho  #Corinthians  #ModernoESerCorinthians  #VaiCorinthians',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf297',
#     'date': '2021-05-24',
#     'text': 'Bora apoiar então!!! #VaiCorinthians #sccp #Corinthians',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf298',
#     'date': '2021-05-24',
#     'text': 'Sylvinho (Novo técnico do @Corinthians ) Seu único trabalho no Lyon: ⚔️ 11 jogos ✅ 3 vitórias ↔️ 4 empates ❌ 4 derrotas 📊 39,40% de aproveitamento 👟 7,8 fin p/ marcar ⚠️ 14,7 fin p/ sofrer gol 📈 53,18% de posse de bola em média  #meutimão #Corinthians #Sylvinho  https://t.co/EOS0SfuVNM',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf299',
#     'date': '2021-05-24',
#     'text': '#FechadocomoTimão - O Corinthians anunciou neste domingo a contratação de Sylvinho, de 47 anos, Ex-Lyon, chega para um contrato até o fim de 2022. . #Corinthians #Timao #Alvinegro #Arena #Sylvinho #futebol #radio #internet #youtube #resenha #soccer #Lyon #Timedopovo #Mano #ENois  https://t.co/sbXsSltTyE',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf29a',
#     'date': '2021-05-24',
#     'text': 'Notamos que estamos ficando velhos quando um dos seus ídolos de infância do #Corinthians volta ao clube para ser treinador (foi por causa do #Sylvinho que tentei ser lateral esquerdo jogando no clube quando era uma criança magra)  https://t.co/iwuOEPI9az',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf29b',
#     'date': '2021-05-24',
#     'text': 'Fagner já está de volta ao CT Dr. Joaquim Grava! Após ser contaminado, novamente, pelo vírus da Covid-19, o lateral retorna aos treinamentos depois de 10 dias longe do clube.  #Corinthians #VaiCorinthians  https://t.co/rXlPSAQ19P',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf29c',
#     'date': '2021-05-24',
#     'text': '@PictureSporting @MikeJ_A #Corinthians',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf29d',
#     'date': '2021-05-24',
#     'text': '16. Este é o número cabalístico do #Corinthians no #brasileirao2021  A posição para o Timão ficar no próximo campeonato é a 16ª colocação.. #timao  #timãomilgrau  #MeuTimao',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf29e',
#     'date': '2021-05-24',
#     'text': '#ブラジルリーグ の人気クラブ #コリンチャンス のトレーニングアイテムにポロシャツが新入荷！  #corinthians #ガヴィオンス #ブラジル代表 #サッカーウェア #南米サッカー #コリンチアーノ #フットサルウェア #サッカーセール #polo   https://t.co/0zAEl4m9k7  https://t.co/9V112nOsBR  https://t.co/NYn3T9hzjo',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf29f',
#     'date': '2021-05-24',
#     'text': 'Caiu na rede é peixe! Na noite de ontem as minas do Timão golearam o Real Brasília; veja como foi a partida e uma analise completa do confronto.  #Corinthians #CorinthiansFeminino #VaiCorinthians   https://t.co/yFCtiKrpIj',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a0',
#     'date': '2021-05-24',
#     'text': 'Luego del pedido de algunos hinchas de #Corinthians por el técnico de #Colón, Eduardo Domínguez, el Timao anunció a Sylvinho como nuevo entrenador para suceder a Vágner Mancini. @Corinthians  https://t.co/8ISVBktvkL',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a1',
#     'date': '2021-05-24',
#     'text': 'Tudo liberado a partir de R$ 25,00 mensal. Chama no DM #Flamengo #Corinthians #gremio #Internacional #ceara #Libertadores #galo #atleticomg #brasileirao #filmes #series #tvviainternet #futebol #lutas #IPTV #santosfc #saopaulofc',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a2',
#     'date': '2021-05-24',
#     'text': '"Agora é com você, hein... Representa o Corinthians!"  📸 Daniel Augusto Jr.  #Corinthians #VaiCorinthians  https://t.co/f2vfjevP6d',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a3',
#     'date': '2021-05-24',
#     'text': '#Corinthians Falando da contratação do Sylvinho ,vendo que melhor opção não veio ,é que temos no momento . Logico que não seria de ninguém da torcida uma opção ,mais e melhor ele hoje do que carille e companhia ltda',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a4',
#     'date': '2021-05-24',
#     'text': 'Bem-vindo Sylvinho! Apesar de não ser certo, espero que dê certo no @Corinthians e que possamos ser felizes novamente. #Corinthians #Sylvinho #VaiCorinthians',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a5',
#     'date': '2021-05-24',
#     'text': 'Moletom Criativa Urbana Corinthians Time Casaco Blusa - Masculino #camisa #Corinthians #Presente #futebol #esporte #frio   https://t.co/fdCMLI6aZV',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a6',
#     'date': '2021-05-24',
#     'text': 'Bom dia, Fiel! 🏴🏳  Uma boa semana a todos e vai Corinthians!  #Corinthians #VaiCorinthians  https://t.co/3AROS9Avrw',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a7',
#     'date': '2021-05-24',
#     'text': 'Ex-jogador do @Corinthians substitui Vagner Mancini, demitido após eliminação no @Paulistao   #Sylvinho #Corinthians #novotécnico  https://t.co/iP5vLYQt95',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a8',
#     'date': '2021-05-24',
#     'text': '2 #Corinthians 9:13 Through the evidence of this service they will glorify ##God because of your obedience to your confession in the #gospel of #Christ and the generosity of your sharing with them and with everyone.',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2a9',
#     'date': '2021-05-24',
#     'text': '@sylvinho_campos fechou com o @corinthians ! Boa sorte garoto!  #futebol  #futebolpaulista  #futebolbrasileiro  #corinthians  #sccp  https://t.co/Zube5mLhhP',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2aa',
#     'date': '2021-05-24',
#     'text': 'Bom Dia, Fiel!  #Corinthians  https://t.co/ojLrofrlEH',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2ab',
#     'date': '2021-05-24',
#     'text': '#Sylvinho #Corinthians  📷corinthians  https://t.co/ou4DSNV2hz',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2ac',
#     'date': '2021-05-24',
#     'text': 'Ufficiale: Sylvinho è il nuovo allenatore del Corinthians #Sylvinho #Corinthians  https://t.co/sVIeoOMxBS',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2ad',
#     'date': '2021-05-24',
#     'text': "Luizinho Polegar Anos 50's Restaurada e colorizada #Corinthians  https://t.co/Dm6FLBHnZe",
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2ae',
#     'date': '2021-05-24',
#     'text': "क्योंकि दाम देकर मोल लिये गए हो, इसलिये अपनी देह के द्वारा परमेश्वर की महिमा करो॥  *(1 #कुरिन्थियों 6:20)*   For ye are bought with a price: therefore glorify God in your body, and in your spirit, which are God's.  *(1 #Corinthians 6:20)* #HolyBible",
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2af',
#     'date': '2021-05-24',
#     'text': '@MeuTimao Só nos resta torcer e apoiar, mas com esse elenco bisonho sabemos que não será fácil. Bem vindo Silvinho. #Corinthians #Sylvinho',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b0',
#     'date': '2021-05-24',
#     'text': 'Liga no cartola ?????? Alguém ??????  #brasileirao2021 #futebol #Cartola #Corinthians #FutebolÉPraTodos',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b1',
#     'date': '2021-05-24',
#     'text': 'Sylvinho #Corinthians',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b2',
#     'date': '2021-05-24',
#     'text': '@Fefis3010 @Corinthians Sou exigente, então ele vai ter que fazer muitoooo pra me convencer u_u  #Corinthians',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b3',
#     'date': '2021-05-24',
#     'text': 'Coincidência, Sylvinho começou sua carreira de treinador com Vagner Mancini. #Corinthians  #MeuTimão',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b4',
#     'date': '2021-05-24',
#     'text': 'Sem dúvidas umas das melhores, senão a melhor opção para o @Corinthians. Veremos se ele consegue fazer esse time (mediano para fraco) jogar. Torço para que sim! #ModernoESerCorinthians #Corinthians #futebol',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b5',
#     'date': '2021-05-24',
#     'text': 'Bom Fiz esse perfil para falar do Corinthians, de uma maneira mais descontraída, e tbm óbvio dar aquela zoada nós antis, sigam aiii. SÓ PRA CAUSAR CAOS, Sylvinho pra mim foi uma boa escolha. #Corinthians  #Sylvinho  #SYLVINHONAO 60% de chance de dar certo, e oque e penso.',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b6',
#     'date': '2021-05-24',
#     'text': '#Futebol #PontePreta #AtléticoMineiro #AtléticoParanaense #Flamengo #Vasco #Fluminense #Botafogo #Corinthians #Palmeiras #SãoPaulo #Santos #Coritiba #Cruzeiro #Juventude #Figueirense #Vitória #Fortaleza #Internacional #Grêmio #Guarani #Goiás #Sport #Bahia #Serra #Paysandu ?',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b7',
#     'date': '2021-05-24',
#     'text': 'Após o anúncio de Sylvinho como nosso novo técnico, vim falar um pouquinho sobre ele e sua trajetória. Dá uma olhadinha, vai! 🖤  #Corinthians #SYLVINHO #VaiCorinthians  https://t.co/xMaMvPMDZW',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b8',
#     'date': '2021-05-24',
#     'text': '@joamlkresponsa sou do nordeste e sou #Corinthians com #Orgulho',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2b9',
#     'date': '2021-05-24',
#     'text': 'Torcida corinthiana já invadiu o insta da filha do sylvinho  😂 Essa torcida é a melhor  #corinthians  https://t.co/eq1qqj33n5',
#     'predict': 0,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2ba',
#     'date': '2021-05-24',
#     'text': 'Des de 1997 tá ! @Corinthians #Corinthians  https://t.co/bvXnYg2SKj',
#     'predict': 1,
#     'query': '#corinthians'},
#    {'_id': '60abfd0918c8e8b052dbf2bb',
#     'date': '2021-05-24',
#     'text': 'Voto De confiança! So aguardar Tirar nosso @Corinthians dessa má Fase!  #Corinthians #Sylvinho #VaiCorinthians #BemVindoDeVoltaSylvinho 🦅⚪⚫⚽  https://t.co/m1JdyfUU6Y',
#     'predict': 0,
#     'query': '#corinthians'}],
#   'messages': 'Lista de objetos retornados com sucesso',
#   'status': '200'}]

# %%
send_post[0]['resultado'][0]
# Out:
# {'_id': '60abfd0918c8e8b052dbf258',
#  'date': '2021-05-24',
#  'text': 'Cartola fc 2021 vai começar e você não sabe em qual liga participar? Entre em A Liga do Willian e participe.   #cartola #cartolafc #brasileirao #futebol #corinthians #palmeiras #santos #saopaulo #flamengo  https://t.co/hPQmH1xHkG',
#  'predict': 1,
#  'query': '#corinthians'}

# %%
df = pd.DataFrame.from_dict(send_post[0]['resultado'])

# %%
df.head()
# Out:
#                         _id        date  \
# 0  60abfd0918c8e8b052dbf258  2021-05-24
# 1  60abfd0918c8e8b052dbf259  2021-05-24
# 2  60abfd0918c8e8b052dbf25a  2021-05-24
# 3  60abfd0918c8e8b052dbf25b  2021-05-24
# 4  60abfd0918c8e8b052dbf25c  2021-05-24
#
#                                                 text  predict         query
# 0  Cartola fc 2021 vai começar e você não sabe em...        1  #corinthians
# 1  O #Flamengo acertou o retorno para o SUB15 de ...        0  #corinthians
# 2  All the wisdom in the world is NOTHING—without...        1  #corinthians
# 3  #EXPERIÊNCIA E #FUTEBOL - #Sylvinho é o novo #...        0  #corinthians
# 4  @Corinthians anunciou neste domingo, 23, a con...        1  #corinthians

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
# _id        100 non-null object
# date       100 non-null object
# text       100 non-null object
# predict    100 non-null int64
# query      100 non-null object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
def create_graph(df):
    
    df.drop(['_id', 'text'], axis=1, inplace=True)
    
    # Ordenando o dataframe pela data
    df = df.sort_values(by=['date'], ascending=True)
    
    labels = list(df.date.unique())
    list_positivo = []
    list_negativo = []


    series_count = df.groupby('date').predict.value_counts()
    for i in range(len(series_count)):
        if series_count.index[i][1] == 0:
            list_positivo.append(series_count[i])
        else:
            list_negativo.append(series_count[i])


    x = np.arange(len(labels)) # localização das labels
    width = 0.35  # largura das barras

    fig, ax = plt.subplots()
    rects1 = ax.bar(x - width/2, list_positivo, width, label='Postivo', alpha=0.7)
    rects2 = ax.bar(x + width/2, list_negativo, width, label='Negativo', alpha=0.7)

    # Adiciona texto para as labels, título e customizações dos tickets das labels.
    ax.set_ylabel('Quantidade de comentários')
    ax.set_title('Quantidade de comentários por classe, dia e a query: ' + df['query'][0])
    ax.set_xticks(x)
    ax.set_xticklabels(labels)
    ax.legend()

    fig.tight_layout()

    plt.show()

# %%
create_graph(df)
